# %%
import pickle

# %%
f=open('stix_aspect_190312_only_science.pkl','r')

# %%
data = pickle.load(f)

# %%
len(data)
# Out:
# 116

# %%
import pprint
pprint.pprint(data[0])
# Out:
# {'header': {'APID': 1500,
#             'APID_packet_category': 12,
#             'APID_process_ID': 93,
#             u'DESCR': u'STIX Science Data Transfer - Aspect',
#             'PUS': 16,
#             u'SPID': 54125,
#             u'SSID': 42,
#             u'TPSD': 54125,
#             'coarse_time': 2147490094,
#             u'data_length': 4090,
#             'destination': 0,
#             'fine_time': 19922,
#             'header_flag': 1,
#             'length': 4099,
#             'packet_id': 3548,
#             'packet_type': 0,
#             'process_id': 221,
#             'seg_flag': 3,
#             u'segmentation': 'stand-alone packet',
#             'seq_count': 0,
#             'service_subtype': 6,
#             'service_type': 21,
#             u'time': 2147490094.3039856,
#             'version': 0},
#  'parameter': {u'NIX00088': [16],
#                u'NIX00089': [510],
#                u'NIX00090': [7429,
#                              7430,
# ...

# %%
DA0=[]
DA1=[]
DB0=[]
DB1=[]
for packet in data:
    DA0.extend(packet['parameter']['NIX00090'])
    DA1.extend(packet['parameter']['NIX00091'])
    DB0.extend(packet['parameter']['NIX00092'])
    DB1.extend(packet['parameter']['NIX00093'])
print(len(Diode_1_voltage))
print(len(Diode_2_voltage))
# Out:
# 58968
# 58968

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12, 12]

# %%
ax1=plt.subplot(221)
plt.plot(range(0,len(DA0)),DA0,'k')
ax1.set_xlabel('Packet Number')
ax1.set_ylabel('Voltage')
ax1.set_title('ChA diode 0')
ax2=plt.subplot(222)
plt.plot(range(0,len(DA1)),DA1,'r')
ax2.set_xlabel('Packet Number')
ax2.set_ylabel('Voltage')
ax2.set_title('ChA diode 1')
ax3=plt.subplot(223)
plt.plot(range(0,len(DB0)),DB0,'b' )
ax3.set_xlabel('Packet Number')
ax3.set_ylabel('Voltage')
ax3.set_title('ChB diode 0')
ax4=plt.subplot(224)
plt.plot(range(0,len(DB1)),DB1 ,'g')
ax4.set_xlabel('Packet Number')
ax4.set_ylabel('Voltage')
ax4.set_title('ChB diode 1')
# Out:
# Text(0.5,1,'ChB diode 1')

# %%
for packet in data:
    print packet['parameter']['NIX00090']
# Out:
# [7429, 7430, 7431, 7434, 7429, 7431, 7430, 7430, 7430, 7431, 7432, 7436, 7439, 7441, 7442, 7443, 7446, 7447, 7449, 7453, 7456, 7458, 7460, 7460, 7460, 7462, 7464, 7466, 7468, 7470, 7472, 7473, 7475, 7479, 7482, 7485, 7483, 7477, 7440, 7423, 7414, 7474, 7491, 7501, 7505, 7508, 7510, 7511, 7512, 7516, 7519, 7522, 7525, 7529, 7531, 7534, 7538, 7540, 7543, 7548, 7553, 7557, 7563, 7571, 7580, 7587, 7592, 7595, 7604, 7608, 7610, 7618, 7616, 7609, 7610, 7609, 7607, 7606, 7609, 7600, 7607, 7617, 7618, 7620, 7623, 7621, 7621, 7622, 7624, 7629, 7632, 7636, 7642, 7654, 7657, 7654, 7661, 7663, 7650, 7645, 7645, 7646, 7647, 7645, 7644, 7644, 7644, 7645, 7644, 7645, 7645, 7646, 7647, 7649, 7651, 7653, 7656, 7660, 7664, 7667, 7667, 7663, 7663, 7663, 7666, 7674, 7675, 7670, 7670, 7670, 7671, 7672, 7673, 7675, 7677, 7680, 7682, 7682, 7683, 7684, 7684, 7685, 7688, 7684, 7684, 7684, 7684, 7684, 7685, 7685, 7687, 7690, 7689, 7689, 7692, 7693, 7694, 7695, 7696, 7696, 7698, 7615, 6856, 6962, 6945, 6971, 6
# ...

# %%
plt.plot(range(0,200),DA0[20000:20200],'k')
