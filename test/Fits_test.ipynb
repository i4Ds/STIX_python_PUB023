# %%
from matplotlib import pyplot as plt 
from astropy.io import fits
import numpy as np
fname='solo_L1_stix-spectrogram-user_20200501T125959__complete_84623364_02701.fits'
hdul=fits.open(fname)

# %%
hdul.info()
# Out:
# Filename: solo_L1_stix-spectrogram-user_20200501T125959__complete_84623364_02701.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()
#   1  RATE          1 BinTableHDU     21   270R x 5C   [E, E, J, 6J, E]
#   2  ENEBAND       1 BinTableHDU     19   6R x 3C   [B, E, E]
#   3  CONTROL       1 BinTableHDU     41   1R x 13C   [I, I, J, 3B, 3B, K, I, 12B, 32B, B, B, B, B]

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# TELESCOP= 'SOLO/STIX'          / Telescope/Sensor name
# INSTRUME= 'STIX    '           / Instrument name
# OBSRVTRY= 'Solar Orbiter'      / Satellite name
# FILENAME= 'solo_L1_stix-spectrogram-user_20200501T125959__complete_84623364_02&'
# CONTINUE  '701.fits&'
# CONTINUE  '' / FITS filename
# DATE    = '2020-07-22T22:26:04.414' / FITS file creation date in UTC
# OBT_BEG = '641653188:0'
# OBT_END = '0641658568:05949'
# TIMESYS = 'UTC     '           / System used for time keywords
# LEVEL   = 'L1      '           / Processing level of the data
# ORIGIN  = 'STIX Team, FHNW'    / Location where file has been generated
# CREATOR = 'STIX-SWF'           / FITS creation software
# VERSION =                    1 / Version of data product
# OBS_MODE= 'Nominal '
# ...

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   40 / length of dimension 1
# NAXIS2  =                  270 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    5 / number of table fields
# TTYPE1  = 'TIME    '
# TFORM1  = 'E       '
# TTYPE2  = 'DELTA_TIME'
# TFORM2  = 'E       '
# TTYPE3  = 'COMBINED_TRIGGERS'
# TFORM3  = 'J       '
# TTYPE4  = 'COUNTS  '
# TFORM4  = '6J      '
# TTYPE5  = 'CLOSE_TIME_OFFSET'
# TFORM5  = 'E       '
# EXTNAME = 'RATE    '           / extension name
# CHECKSUM= 'UFOYaCOWXCOWaCOW'   / HDU checksum updated 2020-07-22T22:26:04
# DATASUM = '3942807417'         / data unit checksum updated 2020-07-22T22:26:04

# %%
hdul[1].header['comments']='new inserted comments'

# %%
data=hdul[1].data
print(data)
# Out:
# [(0., 1.0000e-01,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 4.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 6.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 8.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 1.0010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 1.2010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 1.4010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 1.6010e+02,   0, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 1.8010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.0010e+02,   5, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.2010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.4010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.6010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 2.8010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 3.0010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 3.2010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 3.4010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
#  (0., 3.6010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1)
# ...

# %%
time=[x[1] for x in hdul[1].data]
LC1=[x[3][0] for x in hdul[1].data]

# %%
plt.plot(time, LC1)

# %%
data2=np.transpose(data)

# %%
len(data2)
# Out:
# 270

# %%
data3=np.array(data.tolist())
data4=np.transpose(data3)

# %%
len(data4)
# Out:
# 5

# %%
plt.plot(data4[1], data4[4])

# %%
hdul.info()
# Out:
# Filename: solo_L1_stix-spectrogram-user_20200501T125959__complete_84623364_02701.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()
#   1  RATE          1 BinTableHDU     21   270R x 5C   [E, E, J, 6J, E]
#   2  ENEBAND       1 BinTableHDU     19   6R x 3C   [B, E, E]
#   3  CONTROL       1 BinTableHDU     41   1R x 13C   [I, I, J, 3B, 3B, K, I, 12B, 32B, B, B, B, B]

# %%
hdul['RATE'].data
# Out:
# FITS_rec([(0., 1.0000e-01,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 4.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 6.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 8.0100e+01,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 1.0010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 1.2010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 1.4010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 1.6010e+02,   0, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 1.8010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.0010e+02,   5, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.2010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.4010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.6010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 2.8010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
#           (0., 3.0010e+02,  52, [0, 0, 0, 0, 0, 0], 20.1),
# ...
